# %%
# Import our dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('https://raw.githubusercontent.com/mk-gurucharan/Regression/master/IceCreamData.csv')
X = dataset['Temperature'].values
y = dataset['Revenue'].values
dataset.head(5)
>>
Temperature   Revenue
24.566884     534.799028
26.005191     625.190122
27.790554     660.632289
20.595335     487.706960
11.503498     316.240194sf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Out:
# Metal device set to: Apple M1
# 2022-10-27 15:57:24.982603: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-27 15:57:24.982821: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2022-10-27 16:24:12.603029: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-27 16:24:12.808299: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 24/24 [==============================] - 2s 7ms/step - loss: 1.2278 - accuracy: 0.0120
# Epoch 2/100
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1751 - accuracy: 0.0253
# Epoch 3/100
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1279 - accuracy: 0.0267
# Epoch 4/100
# 24/24 [==============================] - 0s 4ms/step - loss: 1.0841 - accuracy: 0.0427
# Epoch 5/100
# 24/24 [==============================] - 0s 4ms/step - loss: 1.0447 - accuracy: 0.0600
# Epoch 6/100
# 24/24 [==============================] - 0s 4ms/step - loss: 1.0097 - accuracy: 0.0760
# Epoch 7/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9790 - accuracy: 0.1000
# Epoch 8/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.9512 - accuracy: 0.1240
# Epoch 9/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9268 - accuracy: 0.1400
# Epoch 10/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9051 - accuracy: 0.1653
# Epoch 11/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8852 - accuracy: 0.1960
# Epoch 12/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8681 - accuracy: 0.2067
# Epoch 13/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8523 - accuracy: 0.2267
# Epoch 14/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8386 - accuracy: 0.2453
# Epoch 15/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.8260 - accuracy: 0.2693
# Epoch 16/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.8146 - accuracy: 0.2840
# Epoch 17/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.8039 - accuracy: 0.3000
# Epoch 18/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7943 - accuracy: 0.3120
# Epoch 19/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7856 - accuracy: 0.3267
# Epoch 20/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7775 - accuracy: 0.3480
# Epoch 21/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7701 - accuracy: 0.3587
# Epoch 22/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7629 - accuracy: 0.3733
# Epoch 23/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7563 - accuracy: 0.3933
# Epoch 24/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7502 - accuracy: 0.4040
# Epoch 25/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7443 - accuracy: 0.4200
# Epoch 26/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7388 - accuracy: 0.4267
# Epoch 27/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7336 - accuracy: 0.4360
# Epoch 28/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7288 - accuracy: 0.4440
# Epoch 29/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7240 - accuracy: 0.4560
# Epoch 30/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7195 - accuracy: 0.4720
# Epoch 31/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7153 - accuracy: 0.4787
# Epoch 32/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7113 - accuracy: 0.4867
# Epoch 33/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.7075 - accuracy: 0.4933
# Epoch 34/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7037 - accuracy: 0.4973
# Epoch 35/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7001 - accuracy: 0.5067
# Epoch 36/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6964 - accuracy: 0.5187
# Epoch 37/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.5240
# Epoch 38/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6890 - accuracy: 0.5307
# Epoch 39/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6853 - accuracy: 0.5453
# Epoch 40/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6817 - accuracy: 0.5520
# Epoch 41/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6779 - accuracy: 0.5613
# Epoch 42/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6742 - accuracy: 0.5720
# Epoch 43/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6700 - accuracy: 0.5813
# Epoch 44/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6659 - accuracy: 0.5920
# Epoch 45/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6613 - accuracy: 0.6013
# Epoch 46/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6568 - accuracy: 0.6107
# Epoch 47/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6521 - accuracy: 0.6200
# Epoch 48/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6473 - accuracy: 0.6360
# Epoch 49/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6425 - accuracy: 0.6480
# Epoch 50/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6375 - accuracy: 0.6600
# Epoch 51/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.6653
# Epoch 52/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6273 - accuracy: 0.6733
# Epoch 53/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6220 - accuracy: 0.6840
# Epoch 54/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6165 - accuracy: 0.6880
# Epoch 55/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6110 - accuracy: 0.6973
# Epoch 56/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6053 - accuracy: 0.7107
# Epoch 57/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5997 - accuracy: 0.7173
# Epoch 58/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5941 - accuracy: 0.7280
# Epoch 59/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5883 - accuracy: 0.7293
# Epoch 60/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5827 - accuracy: 0.7320
# Epoch 61/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5772 - accuracy: 0.7387
# Epoch 62/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5713 - accuracy: 0.7467
# Epoch 63/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5656 - accuracy: 0.7507
# Epoch 64/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5597 - accuracy: 0.7533
# Epoch 65/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5539 - accuracy: 0.7560
# Epoch 66/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5481 - accuracy: 0.7587
# Epoch 67/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5420 - accuracy: 0.7613
# Epoch 68/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5360 - accuracy: 0.7680
# Epoch 69/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5301 - accuracy: 0.7787
# Epoch 70/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5240 - accuracy: 0.7853
# Epoch 71/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5176 - accuracy: 0.7853
# Epoch 72/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5112 - accuracy: 0.7893
# Epoch 73/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.7960
# Epoch 74/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4983 - accuracy: 0.8027
# Epoch 75/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4918 - accuracy: 0.8053
# Epoch 76/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4854 - accuracy: 0.8080
# Epoch 77/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4788 - accuracy: 0.8213
# Epoch 78/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4722 - accuracy: 0.8253
# Epoch 79/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4656 - accuracy: 0.8347
# Epoch 80/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4589 - accuracy: 0.8387
# Epoch 81/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4524 - accuracy: 0.8400
# Epoch 82/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4460 - accuracy: 0.8453
# Epoch 83/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4397 - accuracy: 0.8507
# Epoch 84/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4335 - accuracy: 0.8520
# Epoch 85/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4273 - accuracy: 0.8547
# Epoch 86/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8587
# Epoch 87/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4146 - accuracy: 0.8640
# Epoch 88/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.8667
# Epoch 89/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4020 - accuracy: 0.8720
# Epoch 90/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3958 - accuracy: 0.8747
# Epoch 91/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3895 - accuracy: 0.8773
# Epoch 92/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3832 - accuracy: 0.8800
# Epoch 93/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.8840
# Epoch 94/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 0.8853
# Epoch 95/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3653 - accuracy: 0.8880
# Epoch 96/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3594 - accuracy: 0.8907
# Epoch 97/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3535 - accuracy: 0.8960
# Epoch 98/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3478 - accuracy: 0.8960
# Epoch 99/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3417 - accuracy: 0.8973
# Epoch 100/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3359 - accuracy: 0.9013

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot: >

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot: >

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.3164 - accuracy: 0.9160 - 129ms/epoch - 16ms/step
# Loss: 0.31636983156204224, Accuracy: 0.9160000681877136
# 2022-10-27 16:26:32.092968: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
