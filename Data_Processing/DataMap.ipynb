# %%
import pandas as pd
import geopandas

# %%
# Create dataframe with data for map
file_path = "./Resources/processed_PLACES_COPD.csv"
predicted_df = pd.read_csv(file_path)
predicted_df
# Out:
#                    State_County          State             County  \
# 0                    Cass, Iowa           Iowa               Cass
# 1                  Monona, Iowa           Iowa             Monona
# 2            Dillingham, Alaska         Alaska         Dillingham
# 3              Custer, Colorado       Colorado             Custer
# 4     Ketchikan Gateway, Alaska         Alaska  Ketchikan Gateway
# ...                         ...            ...                ...
# 3117            Sauk, Wisconsin      Wisconsin               Sauk
# 3118           Brown, Wisconsin      Wisconsin              Brown
# 3119     Webster, West Virginia  West Virginia            Webster
# 3120       Winnebago, Wisconsin      Wisconsin          Winnebago
# 3121        Waukesha, Wisconsin      Wisconsin           Waukesha
#
#       Levels_Smokers  Levels_COPD
# 0               19.3          8.3
# 1               18.5          8.3
# 2               31.1          8.9
# 3               13.8          7.5
# 4               19.4          6.6
# ...              ...          ...
# 3117            16.8          6.5
# 3118            15.1          5.5
# 3119            26.8         15.3
# 3120            17.1          5.8
# 3121            12.6          4.7
#
# [3122 rows x 5 columns]

# %%
predicted_df = predicted_df.drop(["State_County"], axis=1)
predicted_df
# Out:
#               State             County  Levels_Smokers  Levels_COPD
# 0              Iowa               Cass            19.3          8.3
# 1              Iowa             Monona            18.5          8.3
# 2            Alaska         Dillingham            31.1          8.9
# 3          Colorado             Custer            13.8          7.5
# 4            Alaska  Ketchikan Gateway            19.4          6.6
# ...             ...                ...             ...          ...
# 3117      Wisconsin               Sauk            16.8          6.5
# 3118      Wisconsin              Brown            15.1          5.5
# 3119  West Virginia            Webster            26.8         15.3
# 3120      Wisconsin          Winnebago            17.1          5.8
# 3121      Wisconsin           Waukesha            12.6          4.7
#
# [3122 rows x 4 columns]

# %%
# Upload geoJSON file for map
file_path = "../COPD_Mapping/static/data/county.geojson"
county_df = geopandas.read_file(file_path)
county_df.head(25)
# Out:
#    STATEFP10 COUNTYFP10 COUNTYNS10 GEOID10           NAME10  \
# 0         02        013   01419964   02013   Aleutians East
# 1         02        016   01419965   02016   Aleutians West
# 2         28        107   00695776   28107           Panola
# 3         28        101   00695773   28101           Newton
# 4         28        027   00695738   28027          Coahoma
# 5         22        065   00558088   22065          Madison
# 6         51        540   01789068   51540  Charlottesville
# 7         51        510   01498415   51510       Alexandria
# 8         51        530   01498417   51530      Buena Vista
# 9         51        600   01789070   51600          Fairfax
# 10        48        113   01383842   48113           Dallas
# 11        48        227   01383899   48227           Howard
# 12        48        155   01383863   48155            Foard
# 13        48        153   01383862   48153            Floyd
# 14        48        043   01383807   48043         Brewster
# 15        48        159   01383865   48159         Franklin
# 16        48        231   01383901   48231             Hunt
# 17        48        351   01383961   48351           Newton
# 18        48        427   01383999   48427            Starr
# 19        48        271   01383921   48271           Kinney
# 20        48        087   01383829   48087    Collingsworth
# 21        48        451   01384011   48451        Tom Green
# 22        48        083   01383827   48083          Coleman
# 23        48        039   01383805   48039         Brazoria
# 24        48        289   01383930   48289             Leon
#
#                     NAMELSAD10 LSAD10 CLASSFP10 MTFCC10 CSAFP10 CBSAFP10  \
# 0       Aleutians East Borough     04        H1   G4020    None     None
# 1   Aleutians West Census Area     05        H5   G4020    None     None
# 2                Panola County     06        H1   G4020    None     None
# 3                Newton County     06        H1   G4020    None     None
# 4               Coahoma County     06        H1   G4020    None    17260
# 5               Madison Parish     15        H1   G4020    None    45260
# 6         Charlottesville city     25        C7   G4020    None    16820
# 7              Alexandria city     25        C7   G4020     548    47900
# 8             Buena Vista city     25        C7   G4020    None     None
# 9                 Fairfax city     25        C7   G4020     548    47900
# 10               Dallas County     06        H1   G4020     206    19100
# 11               Howard County     06        H1   G4020    None    13700
# 12                Foard County     06        H1   G4020    None     None
# 13                Floyd County     06        H1   G4020    None     None
# 14             Brewster County     06        H1   G4020    None     None
# 15             Franklin County     06        H1   G4020    None     None
# 16                 Hunt County     06        H1   G4020     206    19100
# 17               Newton County     06        H1   G4020    None     None
# 18                Starr County     06        H1   G4020    None    40100
# 19               Kinney County     06        H1   G4020    None     None
# 20        Collingsworth County     06        H1   G4020    None     None
# 21            Tom Green County     06        H1   G4020    None    41660
# 22              Coleman County     06        H1   G4020    None     None
# 23             Brazoria County     06        H1   G4020     288    26420
# 24                 Leon County     06        H1   G4020    None     None
#
#    METDIVFP10 FUNCSTAT10       ALAND10      AWATER10   INTPTLAT10  \
# 0        None          A  1.808315e+10  2.079221e+10  +55.2437223
# 1        None          S  1.137076e+10  2.519064e+10  +51.9594469
# 2        None          A  1.774516e+09  5.176705e+07  +34.3652052
# 3        None          A  1.497283e+09  3.879399e+06  +32.4019702
# 4        None          A  1.430818e+09  7.953947e+07  +34.2286699
# 5        None          A  1.617283e+09  6.853867e+07  +32.3658243
# 6        None          F  2.651736e+07  5.297400e+04  +38.0376579
# 7       47894          F  3.891973e+07  1.140371e+06  +38.8183429
# 8        None          F  1.736224e+07  2.238550e+05  +37.7316634
# 9       47894          F  1.615946e+07  9.505400e+04  +38.8531833
# 10      19124          A  2.256603e+09  9.669635e+07  +32.7669866
# 11       None          A  2.333038e+09  8.841951e+06  +32.3035834
# 12       None          A  1.824379e+09  8.514811e+06  +33.9804040
# 13       None          A  2.569637e+09  9.837400e+05  +34.0737305
# 14       None          A  1.601580e+10  2.206400e+07  +29.8089965
# 15       None          A  7.365690e+08  2.687609e+07  +33.1758457
# 16      19124          A  2.176414e+09  1.080148e+08  +33.1234378
# 17       None          A  2.418212e+09  1.567210e+07  +30.7867182
# 18       None          A  3.168019e+09  1.530228e+07  +26.5463354
# 19       None          A  3.522526e+09  1.312508e+07  +29.3470865
# 20       None          A  2.378751e+09  2.279238e+06  +34.9633577
# 21       None          A  3.941890e+09  4.810479e+07  +31.4015829
# 22       None          A  3.268424e+09  5.047227e+07  +31.9142052
# 23       None          A  3.516430e+09  6.497927e+08  +29.1678175
# 24       None          A  2.779447e+09  1.934305e+07  +31.3004925
#
#       INTPTLON10                                           geometry
# 0   -161.9507485  MULTIPOLYGON (((-162.63769 54.80112, -162.6411...
# 1   +178.3388130  MULTIPOLYGON (((177.44593 52.11133, 177.44302 ...
# 2   -089.9630654  POLYGON ((-90.13476 34.22603, -90.13476 34.226...
# 3   -089.1184115  POLYGON ((-89.13497 32.57697, -89.13466 32.576...
# 4   -090.6031650  POLYGON ((-90.59063 33.98690, -90.59473 33.986...
# 5   -091.2407290  MULTIPOLYGON (((-91.03511 32.12035, -91.03621 ...
# 6   -078.4853806  POLYGON ((-78.47071 38.04872, -78.47033 38.048...
# 7   -077.0820263  POLYGON ((-77.06247 38.79496, -77.06267 38.795...
# 8   -079.3563746  POLYGON ((-79.36681 37.72722, -79.36686 37.727...
# 9   -077.2990252  POLYGON ((-77.31427 38.86700, -77.31414 38.867...
# 10  -096.7784238  POLYGON ((-96.52999 32.54528, -96.53330 32.545...
# 11  -101.4385304  POLYGON ((-101.17470 32.49329, -101.17470 32.4...
# 12  -099.7774272  POLYGON ((-99.59622 33.78740, -99.59627 33.787...
# 13  -101.3032742  POLYGON ((-101.56453 34.05969, -101.56456 34.0...
# 14  -103.2524579  POLYGON ((-103.32538 30.58608, -103.32531 30.5...
# 15  -095.2190662  POLYGON ((-95.30845 33.02455, -95.30844 33.029...
# 16  -096.0838072  POLYGON ((-95.86178 33.21933, -95.86178 33.219...
# 17  -093.7392500  POLYGON ((-93.55074 30.92123, -93.55078 30.921...
# 18  -098.7158034  POLYGON ((-98.85127 26.78533, -98.84910 26.785...
# 19  -100.4177003  POLYGON ((-100.11224 29.46769, -100.11225 29.4...
# 20  -100.2721351  POLYGON ((-100.53965 34.99391, -100.53962 34.9...
# 21  -100.4613549  POLYGON ((-100.44159 31.69307, -100.44153 31.6...
# 22  -099.3466224  POLYGON ((-99.71619 31.89906, -99.71618 31.899...
# 23  -095.4346470  POLYGON ((-95.05714 29.20088, -95.05709 29.200...
# 24  -095.9956219  POLYGON ((-96.26059 31.07707, -96.26094 31.076...

# %%
county_df.STATEFP10.unique().tolist()
# Out:
# ['02',
#  '28',
#  '22',
#  '51',
#  '48',
#  '34',
#  '23',
#  '50',
#  '56',
#  '29',
#  '17',
#  '06',
#  '49',
#  '37',
#  '42',
#  '39',
#  '36',
#  '04',
#  '35',
#  '24',
#  '44',
#  '41',
#  '53',
#  '72',
#  '55',
#  '38',
#  '32',
#  '13',
#  '05',
#  '20',
#  '31',
#  '40',
#  '54',
#  '26',
#  '08',
#  '10',
#  '30',
#  '09',
#  '25',
#  '21',
#  '12',
#  '11',
#  '16',
#  '45',
#  '15',
#  '01',
#  '33',
#  '46',
#  '47',
#  '18',
#  '19',
#  '27']

# %%
county_df.rename(columns = {'NAME10':'County'}, inplace = True)
county_df.head()
# Out:
#   STATEFP10 COUNTYFP10 COUNTYNS10 GEOID10          County  \
# 0        02        013   01419964   02013  Aleutians East
# 1        02        016   01419965   02016  Aleutians West
# 2        28        107   00695776   28107          Panola
# 3        28        101   00695773   28101          Newton
# 4        28        027   00695738   28027         Coahoma
#
#                    NAMELSAD10 LSAD10 CLASSFP10 MTFCC10 CSAFP10 CBSAFP10  \
# 0      Aleutians East Borough     04        H1   G4020    None     None
# 1  Aleutians West Census Area     05        H5   G4020    None     None
# 2               Panola County     06        H1   G4020    None     None
# 3               Newton County     06        H1   G4020    None     None
# 4              Coahoma County     06        H1   G4020    None    17260
#
#   METDIVFP10 FUNCSTAT10       ALAND10      AWATER10   INTPTLAT10  \
# 0       None          A  1.808315e+10  2.079221e+10  +55.2437223
# 1       None          S  1.137076e+10  2.519064e+10  +51.9594469
# 2       None          A  1.774516e+09  5.176705e+07  +34.3652052
# 3       None          A  1.497283e+09  3.879399e+06  +32.4019702
# 4       None          A  1.430818e+09  7.953947e+07  +34.2286699
#
#      INTPTLON10                                           geometry
# 0  -161.9507485  MULTIPOLYGON (((-162.63769 54.80112, -162.6411...
# 1  +178.3388130  MULTIPOLYGON (((177.44593 52.11133, 177.44302 ...
# 2  -089.9630654  POLYGON ((-90.13476 34.22603, -90.13476 34.226...
# 3  -089.1184115  POLYGON ((-89.13497 32.57697, -89.13466 32.576...
# 4  -090.6031650  POLYGON ((-90.59063 33.98690, -90.59473 33.986...

# %%
datamap_df = predicted_df.merge(county_df, on=["State", "County"])
datamap_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 datamap_df = predicted_df.merge(county_df, on=["State", "County"])
#       2 datamap_df.head(5)
#
# File ~/miniforge3/envs/tfenv/lib/python3.10/site-packages/pandas/core/frame.py:10080, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10061 @Substitution("")
#   10062 @Appender(_merge_doc, indents=2)
#   10063 def merge(
#    (...)
#   10076     validate: str | None = None,
#   10077 ) -> DataFrame:
#   10078     from pandas.core.reshape.merge import merge
# > 10080     return merge(
#   10081         self,
#   10082         right,
#   10083         how=how,
#   10084         on=on,
#   10085         left_on=left_on,
#   10086         right_on=right_on,
#   10087         left_index=left_index,
#   10088         right_index=right_index,
#   10089         sort=sort,
#   10090         suffixes=suffixes,
#   10091         copy=copy,
#   10092         indicator=indicator,
#   10093         validate=validate,
#   10094     )
#
# File ~/miniforge3/envs/tfenv/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~/miniforge3/envs/tfenv/lib/python3.10/site-packages/pandas/core/reshape/merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~/miniforge3/envs/tfenv/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~/miniforge3/envs/tfenv/lib/python3.10/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'State'

# %%
# # Export the dataframe to csv
# datamap_df.to_csv('../COPD_Mapping/static/data/data_map.geojson', index=False)
