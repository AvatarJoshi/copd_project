# %%
import pandas as pd
import numpy as np

# %%
# Import explore_ml results file
explore_df = pd.read_csv("./Resources/explore_ML_results.csv")
explore_df.head(119)
# Out:
#                    State_County   StateDesc       LocationName  \
# 0                    Iowa, Cass        Iowa               Cass
# 1                  Iowa, Monona        Iowa             Monona
# 2            Alaska, Dillingham      Alaska         Dillingham
# 3              Colorado, Custer    Colorado             Custer
# 4     Alaska, Ketchikan Gateway      Alaska  Ketchikan Gateway
# ..                          ...         ...                ...
# 114            Alabama, Madison     Alabama            Madison
# 115          California, Sutter  California             Sutter
# 116          Colorado, Gunnison    Colorado           Gunnison
# 117            Arizona, Yavapai     Arizona            Yavapai
# 118  California, San Bernardino  California     San Bernardino
#
#      Levels_Smokers  Levels_COPD  Low CL COPD  High CL COPD
# 0              19.3          8.3          7.0           9.8
# 1              18.5          8.3          7.0           9.5
# 2              31.1          8.9          7.7          10.0
# 3              13.8          7.5          6.1           9.0
# 4              19.4          6.6          5.8           7.5
# ..              ...          ...          ...           ...
# 114            15.7          6.7          5.7           7.7
# 115            14.4          6.2          5.5           7.0
# 116            13.1          4.5          3.8           5.4
# 117            15.5          9.3          7.8          10.9
# 118            13.3          4.9          4.4           5.4
#
# [119 rows x 7 columns]

# %%
explore_df.shape
# Out:
# (3122, 7)

# %%
explore_df[explore_df['LocationName'].isnull()]
# Out:
#    State_County      StateDesc LocationName  Levels_Smokers  Levels_COPD  \
# 33          NaN  United States          NaN            15.3          6.6
#
#     Low CL COPD  High CL COPD
# 33          6.5           6.7

# %%
# Drop the row containing "United States"
explore_df = explore_df[explore_df.LocationName != "United States"]

# %%
# Checking that this dataframe was merged correctly and that all Levels of COPD fall in CL range
accurate_predictions = explore_df[(explore_df['Levels_COPD'] >= explore_df['Low CL COPD']) & 
           (explore_df['Levels_COPD'] <= explore_df['High CL COPD'])].count()
accurate_predictions
# Out:
# State_County      3121
# StateDesc         3122
# LocationName      3121
# Levels_Smokers    3122
# Levels_COPD       3122
# Low CL COPD       3122
# High CL COPD      3122
# dtype: int64

# %%
explore_df.shape
# Out:
# (3122, 7)

# %%
# Import RandomForestRegression-Complex Results
results_df = pd.read_csv("./Resources/RandomForest_Pred_vs_Actual_y_Results.csv")

results_df = results_df.set_index("Unnamed: 0")
results_df.index.name = None

results_df.head(119)
# Out:
#       Real Values  Predicted Values
# 1095         14.0             14.00
# 642           6.9              8.92
# 1573          7.3              7.70
# 576           6.8              7.77
# 118           4.9              5.17
# ...           ...               ...
# 2484          7.9              7.92
# 2577          6.3              7.45
# 2048         10.1              9.35
# 1784         13.9             13.20
# 2606          7.0              7.30
#
# [119 rows x 2 columns]

# %%
results_df.shape
# Out:
# (954, 2)

# %%
explore_df.columns.tolist()
# Out:
# ['State_County',
#  'StateDesc',
#  'LocationName',
#  'Levels_Smokers',
#  'Levels_COPD',
#  'Low CL COPD',
#  'High CL COPD']

# %%
explore_df = explore_df[['State_County',
                         'StateDesc',
                         'LocationName',
                         'Levels_Smokers',
                         'Levels_COPD',
                         'Low CL COPD',
                         'High CL COPD'
                        ]]
explore_df
# Out:
#                    State_County      StateDesc       LocationName  \
# 0                    Iowa, Cass           Iowa               Cass
# 1                  Iowa, Monona           Iowa             Monona
# 2            Alaska, Dillingham         Alaska         Dillingham
# 3              Colorado, Custer       Colorado             Custer
# 4     Alaska, Ketchikan Gateway         Alaska  Ketchikan Gateway
# ...                         ...            ...                ...
# 3117            Wisconsin, Sauk      Wisconsin               Sauk
# 3118           Wisconsin, Brown      Wisconsin              Brown
# 3119     West Virginia, Webster  West Virginia            Webster
# 3120       Wisconsin, Winnebago      Wisconsin          Winnebago
# 3121        Wisconsin, Waukesha      Wisconsin           Waukesha
#
#       Levels_Smokers  Levels_COPD  Low CL COPD  High CL COPD
# 0               19.3          8.3          7.0           9.8
# 1               18.5          8.3          7.0           9.5
# 2               31.1          8.9          7.7          10.0
# 3               13.8          7.5          6.1           9.0
# 4               19.4          6.6          5.8           7.5
# ...              ...          ...          ...           ...
# 3117            16.8          6.5          5.5           7.6
# 3118            15.1          5.5          4.7           6.5
# 3119            26.8         15.3         13.1          17.3
# 3120            17.1          5.8          4.9           6.7
# 3121            12.6          4.7          3.9           5.6
#
# [3122 rows x 7 columns]

# %%
explore_df = explore_df.rename(columns={'StateDesc': 'State', 
                                        'LocationName': 'County'})

# %%
explore_df
# Out:
#                    State_County          State             County  \
# 0                    Iowa, Cass           Iowa               Cass
# 1                  Iowa, Monona           Iowa             Monona
# 2            Alaska, Dillingham         Alaska         Dillingham
# 3              Colorado, Custer       Colorado             Custer
# 4     Alaska, Ketchikan Gateway         Alaska  Ketchikan Gateway
# ...                         ...            ...                ...
# 3117            Wisconsin, Sauk      Wisconsin               Sauk
# 3118           Wisconsin, Brown      Wisconsin              Brown
# 3119     West Virginia, Webster  West Virginia            Webster
# 3120       Wisconsin, Winnebago      Wisconsin          Winnebago
# 3121        Wisconsin, Waukesha      Wisconsin           Waukesha
#
#       Levels_Smokers  Levels_COPD  Low CL COPD  High CL COPD
# 0               19.3          8.3          7.0           9.8
# 1               18.5          8.3          7.0           9.5
# 2               31.1          8.9          7.7          10.0
# 3               13.8          7.5          6.1           9.0
# 4               19.4          6.6          5.8           7.5
# ...              ...          ...          ...           ...
# 3117            16.8          6.5          5.5           7.6
# 3118            15.1          5.5          4.7           6.5
# 3119            26.8         15.3         13.1          17.3
# 3120            17.1          5.8          4.9           6.7
# 3121            12.6          4.7          3.9           5.6
#
# [3122 rows x 7 columns]

# %%
# Merge dataframes
merged_df = pd.merge(explore_df, results_df, left_index=True, right_index=True)
merged_df
# Out:
#                 State_County          State    County  Levels_Smokers  \
# 1               Iowa, Monona           Iowa    Monona            18.5
# 9            Arkansas, Perry       Arkansas     Perry            22.6
# 10         Arkansas, Carroll       Arkansas   Carroll            19.2
# 14         Arkansas, Madison       Arkansas   Madison            23.5
# 15           Colorado, Otero       Colorado     Otero            16.3
# ...                      ...            ...       ...             ...
# 3105     Wisconsin, Bayfield      Wisconsin  Bayfield            15.9
# 3116         Wyoming, Platte        Wyoming    Platte            18.2
# 3117         Wisconsin, Sauk      Wisconsin      Sauk            16.8
# 3119  West Virginia, Webster  West Virginia   Webster            26.8
# 3121     Wisconsin, Waukesha      Wisconsin  Waukesha            12.6
#
#       Levels_COPD  Low CL COPD  High CL COPD  Real Values  Predicted Values
# 1             8.3          7.0           9.5          8.3              7.96
# 9            11.1          9.6          12.6         11.1             10.83
# 10            9.8          8.4          11.2          9.8              8.09
# 14           11.3          9.8          13.0         11.3             11.62
# 15            7.1          6.3           7.9          7.1              7.19
# ...           ...          ...           ...          ...               ...
# 3105          7.5          6.3           8.7          3.9              4.04
# 3116          8.5          7.3           9.8          5.8              6.58
# 3117          6.5          5.5           7.6         11.5             10.72
# 3119         15.3         13.1          17.3         13.1             12.17
# 3121          4.7          3.9           5.6          8.3              7.81
#
# [934 rows x 9 columns]

# %%
# Check that merge occurred correctly
merged_df[(merged_df['Levels_COPD'] == merged_df['Real Values'])].count()
# Out:
# State_County        59
# State               59
# County              59
# Levels_Smokers      59
# Levels_COPD         59
# Low CL COPD         59
# High CL COPD        59
# Real Values         59
# Predicted Values    59
# dtype: int64

# %%
# Drop unneeded columns
merged_df = merged_df.drop(['Levels_Smokers', 'Levels_COPD'], axis=1)

# %%
# Check merge worked properly by seeing that all rows have a predicted value
merged_df["Predicted Values"].isnull().sum()
# Out:
# 0

# %%
# View a random sample of data
merged_df.sample(5)
# Out:
#               State_County          State    County  Low CL COPD  \
# 3084  West Virginia, Tyler  West Virginia     Tyler         10.6
# 1450     Minnesota, Martin      Minnesota    Martin          6.0
# 1095    Louisiana, Jackson      Louisiana   Jackson          9.3
# 1684        Missouri, Knox       Missouri      Knox         10.0
# 1010      Kansas, Phillips         Kansas  Phillips          7.1
#
#       High CL COPD  Real Values  Predicted Values
# 3084          13.9          6.8              7.09
# 1450           8.4          7.4              7.48
# 1095          11.9         14.0             14.00
# 1684          13.7         11.1              8.54
# 1010           9.8         11.8             12.39

# %%
total_predictions = merged_df["Predicted Values"].count()

# %%
accurate_predictions = merged_df[(merged_df['Predicted Values'] >= merged_df['Low CL COPD']) & 
           (merged_df['Predicted Values'] <= merged_df['High CL COPD'])].count()

# %%
num_accurate_pred = (accurate_predictions[6] / total_predictions) * 100
print(f"The RandomForestRegression model had {num_accurate_pred:.2f}% of predictions within the confidence interval")
# Out:
# The RandomForestRegression model had 34.48% of predictions within the confidence interval

# %%
accurate_predictions[6]
# Out:
# 322

# %%
merged_df[(merged_df['Predicted Values'] >= merged_df['Low CL COPD'])].count()
# Out:
# State_County        649
# State               649
# County              649
# Low CL COPD         649
# High CL COPD        649
# Real Values         649
# Predicted Values    649
# dtype: int64

# %%
merged_df[(merged_df['Predicted Values'] <= merged_df['Low CL COPD'])].count()
# Out:
# State_County        286
# State               286
# County              286
# Low CL COPD         286
# High CL COPD        286
# Real Values         286
# Predicted Values    286
# dtype: int64

# %%
merged_df[(merged_df['Predicted Values'] >= merged_df['High CL COPD'])].count()
# Out:
# State_County        329
# State               329
# County              329
# Low CL COPD         329
# High CL COPD        329
# Real Values         329
# Predicted Values    329
# dtype: int64

# %%
merged_df[(merged_df['Predicted Values'] <= merged_df['High CL COPD'])].count()
# Out:
# State_County        607
# State               607
# County              607
# Low CL COPD         607
# High CL COPD        607
# Real Values         607
# Predicted Values    607
# dtype: int64
