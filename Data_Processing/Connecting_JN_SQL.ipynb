# %%
# !pip install ipython-sql
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: ipython-sql in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: six in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlparse in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable<1 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython-sql) (1.3.9)
# Requirement already satisfied: ipython>=1.0 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython-sql) (8.5.0)
# Requirement already satisfied: traitlets>=5 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (5.4.0)
# Requirement already satisfied: pickleshare in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: backcall in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (2.13.0)
# Requirement already satisfied: appnope in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.1.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (3.0.31)
# Requirement already satisfied: jedi>=0.16 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.1.6)
# Requirement already satisfied: decorator in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: stack-data in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: pure-eval in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)
# Requirement already satisfied: asttokens in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.8)
# Requirement already satisfied: executing in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql) (1.1.1)
# Requirement already satisfied: psycopg2-binary in /Users/avatarjoshi/miniforge3/lib/python3.10/site-packages (2.9.5)

# %%
# %load_ext sql

# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = sqlalchemy.create_engine('postgresql://postgres:Lunex!@localhost:5433/COPD_Project')

# %%
# %sql $engine.url
# Out:
# (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# Create the dataframe
file_path = "./Resources/processed_Coal_Mines.csv"
coal_df = pd.read_csv(file_path)
coal_df.head()
# Out:
#               State_County          State      County  Surface_Mines  \
# 0          Alabama, Walker        Alabama      Walker            7.0
# 1       Alabama, Jefferson        Alabama   Jefferson            7.0
# 2      Alabama, Tuscaloosa        Alabama  Tuscaloosa            4.0
# 3  West Virginia, Nicholas  West Virginia    Nicholas            4.0
# 4         Alabama, De Kalb        Alabama     De Kalb            1.0
#
#    Underground_Mines
# 0                2.0
# 1                3.0
# 2                1.0
# 3                1.0
# 4                0.0

# %%
coal_df.to_sql('coal_mines', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:325, in Pool.connect(self)
#     318 """Return a DBAPI connection from the pool.
#     319
#     320 The connection is instrumented such that when its
#    (...)
#     323
#     324 """
# --> 325 return _ConnectionFairy._checkout(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:888, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     887 if not fairy:
# --> 888     fairy = _ConnectionRecord.checkout(pool)
#     890     fairy._pool = pool
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:491, in _ConnectionRecord.checkout(cls, pool)
#     489 @classmethod
#     490 def checkout(cls, pool):
# --> 491     rec = pool._do_get()
#     492     try:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:271, in Pool._create_connection(self)
#     269 """Called by subclasses to create a new ConnectionRecord."""
# --> 271 return _ConnectionRecord(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:386, in _ConnectionRecord.__init__(self, pool, connect)
#     385 if connect:
# --> 386     self.__connect()
#     387 self.finalize_callback = deque()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:685, in _ConnectionRecord.__connect(self)
#     684     with util.safe_reraise():
# --> 685         pool.logger.debug("Error on connect(): %s", e)
#     686 else:
#     687     # in SQLAlchemy 1.4 the first_connect event is not used by
#     688     # the engine, so this will usually not be set
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:680, in _ConnectionRecord.__connect(self)
#     679 self.starttime = time.time()
# --> 680 self.dbapi_connection = connection = pool._invoke_creator(self)
#     681 pool.logger.debug("Created new connection %r", connection)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/create.py:578, in create_engine.<locals>.connect(connection_record)
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 coal_df.to_sql('coal_mines', con = engine, if_exists = 'append', chunksize = 1000)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:1760, in SQLDatabase.has_table(self, name, schema)
#    1757 def has_table(self, name: str, schema: str | None = None):
#    1758     from sqlalchemy import inspect as sqlalchemy_inspect
# -> 1760     insp = sqlalchemy_inspect(self.connectable)
#    1761     return insp.has_table(name, schema or self.meta.schema)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/inspection.py:64, in inspect(subject, raiseerr)
#      62 if reg is True:
#      63     return subject
# ---> 64 ret = reg(subject)
#      65 if ret is not None:
#      66     break
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:182, in Inspector._engine_insp(bind)
#     180 @inspection._inspects(Engine)
#     181 def _engine_insp(bind):
# --> 182     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:117, in Inspector._construct(cls, init, bind)
#     114     cls = bind.dialect.inspector
#     116 self = cls.__new__(cls)
# --> 117 init(self, bind)
#     118 return self
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:128, in Inspector._init_engine(self, engine)
#     126 def _init_engine(self, engine):
#     127     self.bind = self.engine = engine
# --> 128     engine.connect().close()
#     129     self._op_context_requires_connect = True
#     130     self.dialect = self.engine.dialect
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3315, in Engine.connect(self, close_with_result)
#    3300 def connect(self, close_with_result=False):
#    3301     """Return a new :class:`_engine.Connection` object.
#    3302
#    3303     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3312
#    3313     """
# -> 3315     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3394, in Engine.raw_connection(self, _connection)
#    3372 def raw_connection(self, _connection=None):
#    3373     """Return a "raw" DBAPI connection from the connection pool.
#    3374
#    3375     The returned object is a proxied version of the DBAPI
#    (...)
#    3392
#    3393     """
# -> 3394     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3364, in Engine._wrap_pool_connect(self, fn, connection)
#    3362 except dialect.dbapi.Error as e:
#    3363     if connection is None:
# -> 3364         Connection._handle_dbapi_exception_noconnection(
#    3365             e, dialect, self
#    3366         )
#    3367     else:
#    3368         util.raise_(
#    3369             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3370         )
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2198, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2196     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2197 elif should_wrap:
# -> 2198     util.raise_(
#    2199         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2200     )
#    2201 else:
#    2202     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     207     exception.__cause__ = replace_context
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#     215     del exception, replace_context, from_, with_traceback
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3359 dialect = self.dialect
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#    3363     if connection is None:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:325, in Pool.connect(self)
#     317 def connect(self):
#     318     """Return a DBAPI connection from the pool.
#     319
#     320     The connection is instrumented such that when its
#    (...)
#     323
#     324     """
# --> 325     return _ConnectionFairy._checkout(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:888, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     885 @classmethod
#     886 def _checkout(cls, pool, threadconns=None, fairy=None):
#     887     if not fairy:
# --> 888         fairy = _ConnectionRecord.checkout(pool)
#     890         fairy._pool = pool
#     891         fairy._counter = 0
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:491, in _ConnectionRecord.checkout(cls, pool)
#     489 @classmethod
#     490 def checkout(cls, pool):
# --> 491     rec = pool._do_get()
#     492     try:
#     493         dbapi_connection = rec.get_connection()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     144     except:
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#     148     return self._do_get()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     207     exception.__cause__ = replace_context
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#     215     del exception, replace_context, from_, with_traceback
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:271, in Pool._create_connection(self)
#     268 def _create_connection(self):
#     269     """Called by subclasses to create a new ConnectionRecord."""
# --> 271     return _ConnectionRecord(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:386, in _ConnectionRecord.__init__(self, pool, connect)
#     384 self.__pool = pool
#     385 if connect:
# --> 386     self.__connect()
#     387 self.finalize_callback = deque()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:685, in _ConnectionRecord.__connect(self)
#     683 except Exception as e:
#     684     with util.safe_reraise():
# --> 685         pool.logger.debug("Error on connect(): %s", e)
#     686 else:
#     687     # in SQLAlchemy 1.4 the first_connect event is not used by
#     688     # the engine, so this will usually not be set
#     689     if pool.dispatch.first_connect:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     207     exception.__cause__ = replace_context
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#     215     del exception, replace_context, from_, with_traceback
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:680, in _ConnectionRecord.__connect(self)
#     678 try:
#     679     self.starttime = time.time()
# --> 680     self.dbapi_connection = connection = pool._invoke_creator(self)
#     681     pool.logger.debug("Created new connection %r", connection)
#     682     self.fresh = True
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/create.py:578, in create_engine.<locals>.connect(connection_record)
#     576         if connection is not None:
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
coal_df = pd.read_sql_query("SELECT * from coal_mines", engine)
coal_df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:325, in Pool.connect(self)
#     318 """Return a DBAPI connection from the pool.
#     319
#     320 The connection is instrumented such that when its
#    (...)
#     323
#     324 """
# --> 325 return _ConnectionFairy._checkout(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:888, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     887 if not fairy:
# --> 888     fairy = _ConnectionRecord.checkout(pool)
#     890     fairy._pool = pool
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:491, in _ConnectionRecord.checkout(cls, pool)
#     489 @classmethod
#     490 def checkout(cls, pool):
# --> 491     rec = pool._do_get()
#     492     try:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:271, in Pool._create_connection(self)
#     269 """Called by subclasses to create a new ConnectionRecord."""
# --> 271 return _ConnectionRecord(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:386, in _ConnectionRecord.__init__(self, pool, connect)
#     385 if connect:
# --> 386     self.__connect()
#     387 self.finalize_callback = deque()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:685, in _ConnectionRecord.__connect(self)
#     684     with util.safe_reraise():
# --> 685         pool.logger.debug("Error on connect(): %s", e)
#     686 else:
#     687     # in SQLAlchemy 1.4 the first_connect event is not used by
#     688     # the engine, so this will usually not be set
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:680, in _ConnectionRecord.__connect(self)
#     679 self.starttime = time.time()
# --> 680 self.dbapi_connection = connection = pool._invoke_creator(self)
#     681 pool.logger.debug("Created new connection %r", connection)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/create.py:578, in create_engine.<locals>.connect(connection_record)
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 coal_df = pd.read_sql_query("SELECT * from coal_mines", engine)
#       2 coal_df.head()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:1560, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1512 """
#    1513 Read SQL query into a DataFrame.
#    1514
#    (...)
#    1556
#    1557 """
#    1558 args = _convert_params(sql, params)
# -> 1560 result = self.execute(*args)
#    1561 columns = result.keys()
#    1563 if chunksize is not None:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/pandas/io/sql.py:1405, in SQLDatabase.execute(self, *args, **kwargs)
#    1403 def execute(self, *args, **kwargs):
#    1404     """Simple passthrough to SQLAlchemy connectable"""
# -> 1405     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine.execute(self, statement, *multiparams, **params)
#    3230 @util.deprecated_20(
#    3231     ":meth:`_engine.Engine.execute`",
#    3232     alternative="All statement execution in SQLAlchemy 2.0 is performed "
#    (...)
#    3237 )
#    3238 def execute(self, statement, *multiparams, **params):
#    3239     """Executes the given construct and returns a
#    3240     :class:`_engine.CursorResult`.
#    3241
#    (...)
#    3254
#    3255     """
# -> 3256     connection = self.connect(close_with_result=True)
#    3257     return connection.execute(statement, *multiparams, **params)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3315, in Engine.connect(self, close_with_result)
#    3300 def connect(self, close_with_result=False):
#    3301     """Return a new :class:`_engine.Connection` object.
#    3302
#    3303     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3312
#    3313     """
# -> 3315     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3394, in Engine.raw_connection(self, _connection)
#    3372 def raw_connection(self, _connection=None):
#    3373     """Return a "raw" DBAPI connection from the connection pool.
#    3374
#    3375     The returned object is a proxied version of the DBAPI
#    (...)
#    3392
#    3393     """
# -> 3394     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3364, in Engine._wrap_pool_connect(self, fn, connection)
#    3362 except dialect.dbapi.Error as e:
#    3363     if connection is None:
# -> 3364         Connection._handle_dbapi_exception_noconnection(
#    3365             e, dialect, self
#    3366         )
#    3367     else:
#    3368         util.raise_(
#    3369             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3370         )
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2198, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2196     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2197 elif should_wrap:
# -> 2198     util.raise_(
#    2199         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2200     )
#    2201 else:
#    2202     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     207     exception.__cause__ = replace_context
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#     215     del exception, replace_context, from_, with_traceback
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3359 dialect = self.dialect
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#    3363     if connection is None:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:325, in Pool.connect(self)
#     317 def connect(self):
#     318     """Return a DBAPI connection from the pool.
#     319
#     320     The connection is instrumented such that when its
#    (...)
#     323
#     324     """
# --> 325     return _ConnectionFairy._checkout(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:888, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     885 @classmethod
#     886 def _checkout(cls, pool, threadconns=None, fairy=None):
#     887     if not fairy:
# --> 888         fairy = _ConnectionRecord.checkout(pool)
#     890         fairy._pool = pool
#     891         fairy._counter = 0
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:491, in _ConnectionRecord.checkout(cls, pool)
#     489 @classmethod
#     490 def checkout(cls, pool):
# --> 491     rec = pool._do_get()
#     492     try:
#     493         dbapi_connection = rec.get_connection()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     144     except:
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#     148     return self._do_get()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     207     exception.__cause__ = replace_context
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#     215     del exception, replace_context, from_, with_traceback
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:271, in Pool._create_connection(self)
#     268 def _create_connection(self):
#     269     """Called by subclasses to create a new ConnectionRecord."""
# --> 271     return _ConnectionRecord(self)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:386, in _ConnectionRecord.__init__(self, pool, connect)
#     384 self.__pool = pool
#     385 if connect:
# --> 386     self.__connect()
#     387 self.finalize_callback = deque()
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:685, in _ConnectionRecord.__connect(self)
#     683 except Exception as e:
#     684     with util.safe_reraise():
# --> 685         pool.logger.debug("Error on connect(): %s", e)
#     686 else:
#     687     # in SQLAlchemy 1.4 the first_connect event is not used by
#     688     # the engine, so this will usually not be set
#     689     if pool.dispatch.first_connect:
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/util/compat.py:210, in raise_(***failed resolving arguments***)
#     207     exception.__cause__ = replace_context
#     209 try:
# --> 210     raise exception
#     211 finally:
#     212     # credit to
#     213     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     214     # as the __traceback__ object creates a cycle
#     215     del exception, replace_context, from_, with_traceback
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:680, in _ConnectionRecord.__connect(self)
#     678 try:
#     679     self.starttime = time.time()
# --> 680     self.dbapi_connection = connection = pool._invoke_creator(self)
#     681     pool.logger.debug("Created new connection %r", connection)
#     682     self.fresh = True
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/create.py:578, in create_engine.<locals>.connect(connection_record)
#     576         if connection is not None:
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/miniforge3/envs/sqlenv/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5433 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %sql SELECT * FROM coal_mines

# %%
# # Create dataframe
# data=pd.DataFrame({
#     'book_id':[12345,12346,12347],
#     'title':['Python Programming','Learn MySQL','Data Science Cookbook'],
#     'price':[29,23,27]
# })

# data

# %%
# # Insert whole DataFrame into MySQL
# data.to_sql('book_details', con = engine, if_exists = 'append', chunksize = 1000)

# %%
# Create the dataframe
file_path = "./Resources/processed_Decade_Air_Quality.csv"
air_quality_df = pd.read_csv(file_path)
air_quality_df.head()

# %%
air_quality_df.to_sql('air_quality_data', con = engine, if_exists = 'append', chunksize = 1000)

# %%
air_quality_df = pd.read_sql_query("SELECT * from air_quality_data", engine)
air_quality_df.head()

# %%
# %sql SELECT * FROM air_quality_data

# %%
# Create the dataframe
file_path = "./Resources/processed_census_data.csv"
census_df = pd.read_csv(file_path)
census_df.head()

# %%
census_df.shape

# %%
census_df.to_sql('census_data', con = engine, if_exists = 'append', chunksize = 1000)
