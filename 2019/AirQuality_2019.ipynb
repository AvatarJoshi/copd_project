# %% [markdown]
# # Exploring the 2019 Air Quality Data

# %%
# Interpreting the data
# https://www.epa.gov/outdoor-air-quality-data/about-air-data-reports

# %%
# Dependencies
import pandas as pd

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2019.csv"
aqi2019_df = pd.read_csv(file_path)
aqi2019_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2019            271        237             34
# 1  Alabama     Clay  2019            107         97             10
# 2  Alabama  Colbert  2019            263        252             11
# 3  Alabama   DeKalb  2019            361        324             37
# 4  Alabama   Elmore  2019            228        208             20
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# View all column names
aqi2019_df.columns.tolist()
# Out:
# ['State',
#  'County',
#  'Year',
#  'Days with AQI',
#  'Good Days',
#  'Moderate Days',
#  'Unhealthy for Sensitive Groups Days',
#  'Unhealthy Days',
#  'Very Unhealthy Days',
#  'Hazardous Days',
#  'Max AQI',
#  '90th Percentile AQI',
#  'Median AQI',
#  'Days CO',
#  'Days NO2',
#  'Days Ozone',
#  'Days PM2.5',
#  'Days PM10']

# %%
dict = {'Days with AQI': 'DaysWithAQI',
        'Good Days': 'GoodDays',
        'Moderate Days': 'ModerateDays',
        'Unhealthy for Sensitive Groups Days': 'UnhealthyForSensitiveGroupsDays',
        'Unhealthy Days': 'UnhealthyDays',
        'Very Unhealthy Days': 'VeryUnhealthyDays',
        'Max AQI': 'MaxAQI',
        '90th Percentile AQI': '90thPercentileAQI',
        'Median AQI': 'MedianAQI',
        'Days CO': 'DaysCO',
        'Days NO2': 'DaysNO2',
        'Days Ozone': 'DaysOzone',
        'Days PM2.5': 'DaysPM2.5',
        'Days PM10': 'DaysPM10'
       }
 
# call rename () method
aqi2019_df.rename(columns=dict,
          inplace=True)
 
# print Data frame after rename columns
aqi2019_df.head()
# Out:
#      State   County  Year  DaysWithAQI  GoodDays  ModerateDays  \
# 0  Alabama  Baldwin  2019          271       237            34
# 1  Alabama     Clay  2019          107        97            10
# 2  Alabama  Colbert  2019          263       252            11
# 3  Alabama   DeKalb  2019          361       324            37
# 4  Alabama   Elmore  2019          228       208            20
#
#    UnhealthyForSensitiveGroupsDays  UnhealthyDays  VeryUnhealthyDays  \
# 0                                0              0                  0
# 1                                0              0                  0
# 2                                0              0                  0
# 3                                0              0                  0
# 4                                0              0                  0
#
#    Hazardous Days  MaxAQI  90thPercentileAQI  MedianAQI  DaysCO  DaysNO2  \
# 0               0      80                 52         37       0        0
# ...

# %%
# Days with AQI Info
'''Number of days in the year having an Air Quality Index value. 
This is the number of days on which measurements from any monitoring site in the county 
or MSA were reported to the AQS database.'''

# Summary statistics
aqi2019_df["DaysWithAQI"].describe()
# Out:
# count    1019.000000
# mean      319.996075
# std        80.606298
# min         2.000000
# 25%       315.500000
# 50%       362.000000
# 75%       365.000000
# max       365.000000
# Name: DaysWithAQI, dtype: float64

# %%
# Sort by Days with AQI
aqi2019_df.sort_values(by=['DaysWithAQI'], ascending=False).head(10)
# Out:
#             State            County  Year  DaysWithAQI  GoodDays  \
# 509       Montana           Sanders  2019          365       330
# 334      Kentucky          Edmonson  2019          365       290
# 359     Louisiana         Jefferson  2019          365       310
# 358     Louisiana         Iberville  2019          365       306
# 357     Louisiana  East Baton Rouge  2019          365       260
# 356     Louisiana         Calcasieu  2019          365       239
# 758  Pennsylvania            Mercer  2019          365       290
# 762  Pennsylvania      Philadelphia  2019          365       244
# 766  Pennsylvania        Washington  2019          365       252
# 769  Pennsylvania              York  2019          365       299
#
#      ModerateDays  UnhealthyForSensitiveGroupsDays  UnhealthyDays  \
# 509            35                                0              0
# 334            75                                0              0
# ...

# %%
# Sort by Days with AQI
aqi2019_df.sort_values(by=['DaysWithAQI']).head(10)
# Out:
#                  State                 County  Year  DaysWithAQI  GoodDays  \
# 775        Puerto Rico                Guayama  2019            2         2
# 788     South Carolina               Colleton  2019            7         7
# 693           Oklahoma                  Grant  2019           27        27
# 768       Pennsylvania                Wyoming  2019           27        19
# 115           Colorado                Fremont  2019           32        32
# 141  Country Of Mexico  BAJA CALIFORNIA NORTE  2019           32         5
# 696           Oklahoma               Le Flore  2019           38        35
# 43            Arkansas              Craighead  2019           49        43
# 912           Virginia          Hopewell City  2019           57        57
# 894     Virgin Islands               St Croix  2019           57        51
#
#      ModerateDays  UnhealthyForSensitiveGroupsDays  UnhealthyDays  \
# 775             0                                0              0
# ...

# %%
# Sort by Days with AQI and determine the number of counties with 
# a measurement for every day of the year
aqi2019_df[aqi2019_df.DaysWithAQI >= 365].shape
# Out:
# (370, 18)

# %%
# Sort by Days with AQI and determine the number of counties with 
# a measurement for 90% of days in the year
aqi2019_df[aqi2019_df.DaysWithAQI >= 328].shape
# Out:
# (753, 18)

# %%
# Sort by Very Unhealthy Days
aqi2019_df.sort_values(by=['VeryUnhealthyDays'],  ascending=False).head(10)
# Out:
#           State                 County  Year  DaysWithAQI  GoodDays  \
# 84   California         San Bernardino  2019          365        55
# 35      Arizona                  Pinal  2019          365       123
# 557  New Mexico               Dona Ana  2019          365       170
# 68   California            Los Angeles  2019          365        66
# 849       Texas                 Harris  2019          365       180
# 101  California                 Tulare  2019          365       127
# 65   California                   Kern  2019          365       119
# 885        Utah                 Uintah  2019          365       223
# 64   California                   Inyo  2019          365       232
# 21       Alaska  Fairbanks North Star   2019          365       230
#
#      ModerateDays  UnhealthyForSensitiveGroupsDays  UnhealthyDays  \
# 84            177                               71             54
# 35            209                               21              2
# ...

# %%
# Sort by Unhealthy Days
aqi2019_df.sort_values(by=['UnhealthyDays'],  ascending=False).head(10)
# Out:
#           State                 County  Year  DaysWithAQI  GoodDays  \
# 84   California         San Bernardino  2019          365        55
# 81   California              Riverside  2019          365        75
# 68   California            Los Angeles  2019          365        66
# 21       Alaska  Fairbanks North Star   2019          365       230
# 65   California                   Kern  2019          365       119
# 71   California               Mariposa  2019          365       221
# 849       Texas                 Harris  2019          365       180
# 18       Alaska             Anchorage   2019          365       289
# 879        Utah               Duchesne  2019          365       234
# 885        Utah                 Uintah  2019          365       223
#
#      ModerateDays  UnhealthyForSensitiveGroupsDays  UnhealthyDays  \
# 84            177                               71             54
# 81            170                               91             29
# ...

# %%
# Sort by Moderate Days
aqi2019_df.sort_values(by=['ModerateDays'],  ascending=False).head(10)
# Out:
#             State       County  Year  DaysWithAQI  GoodDays  ModerateDays  \
# 31        Arizona     Maricopa  2019          365        66           261
# 85     California    San Diego  2019          365        87           253
# 63     California     Imperial  2019          365       125           219
# 68     California  Los Angeles  2019          365        66           213
# 35        Arizona        Pinal  2019          365       123           209
# 731  Pennsylvania    Allegheny  2019          365       146           208
# 283       Indiana       Marion  2019          365       153           208
# 242      Illinois         Cook  2019          365       150           206
# 524        Nevada        Clark  2019          365       154           206
# 845         Texas      El Paso  2019          365       147           205
#
#      UnhealthyForSensitiveGroupsDays  UnhealthyDays  VeryUnhealthyDays  \
# 31                                38              0                  0
# ...

# %%
# Sort by Days of Ozone
aqi2019_df.sort_values(by=['DaysOzone'],  ascending=False).head(10)
# Out:
#          State                County  Year  DaysWithAQI  GoodDays  \
# 297    Indiana               Warrick  2019          365       337
# 289    Indiana                Shelby  2019          365       338
# 167    Florida               Manatee  2019          365       333
# 265    Indiana                 Brown  2019          365       349
# 486   Missouri                Monroe  2019          365       357
# 840      Texas                Collin  2019          365       309
# 124   Colorado             Montezuma  2019          365       279
# 176    Florida                 Pasco  2019          365       336
# 174    Florida               Osceola  2019          364       338
# 369  Louisiana  St. John the Baptist  2019          364       334
#
#      ModerateDays  UnhealthyForSensitiveGroupsDays  UnhealthyDays  \
# 297            28                                0              0
# 289            27                                0              0
# ...

# %%
# Sort by Days of PM2.5
aqi2019_df.sort_values(by=['DaysPM2.5'],  ascending=False).head(10)
# Out:
#             State      County  Year  DaysWithAQI  GoodDays  ModerateDays  \
# 722        Oregon        Linn  2019          365       280            83
# 983     Wisconsin       Grant  2019          365       304            60
# 932    Washington      Chelan  2019          365       298            66
# 742  Pennsylvania  Cumberland  2019          365       268            92
# 935    Washington    Columbia  2019          365       340            25
# 939    Washington       Grant  2019          365       339            26
# 941    Washington   Jefferson  2019          365       364             1
# 944    Washington    Kittitas  2019          365       305            60
# 945    Washington   Klickitat  2019          365       339            26
# 946    Washington       Lewis  2019          365       343            22
#
#      UnhealthyForSensitiveGroupsDays  UnhealthyDays  VeryUnhealthyDays  \
# 722                                2              0                  0
# ...

# %%
# Sort by Median AQI
aqi2019_df.sort_values(by=['MedianAQI'],  ascending=False).head(10)
# Out:
#                  State                 County  Year  DaysWithAQI  GoodDays  \
# 84          California         San Bernardino  2019          365        55
# 81          California              Riverside  2019          365        75
# 141  Country Of Mexico  BAJA CALIFORNIA NORTE  2019           32         5
# 68          California            Los Angeles  2019          365        66
# 65          California                   Kern  2019          365       119
# 101         California                 Tulare  2019          365       127
# 31             Arizona               Maricopa  2019          365        66
# 85          California              San Diego  2019          365        87
# 35             Arizona                  Pinal  2019          365       123
# 60          California                 Fresno  2019          365       139
#
#      ModerateDays  UnhealthyForSensitiveGroupsDays  UnhealthyDays  \
# 84            177                               71             54
# ...

# %%
# Sort by Max AQI
aqi2019_df.sort_values(by=['MaxAQI'],  ascending=False).head(10)
# Out:
#           State                 County  Year  DaysWithAQI  GoodDays  \
# 74   California                   Mono  2019          365       270
# 35      Arizona                  Pinal  2019          365       123
# 64   California                   Inyo  2019          365       232
# 557  New Mexico               Dona Ana  2019          365       170
# 562  New Mexico                   Luna  2019          361       349
# 65   California                   Kern  2019          365       119
# 66   California                  Kings  2019          365       152
# 21       Alaska  Fairbanks North Star   2019          365       230
# 101  California                 Tulare  2019          365       127
# 84   California         San Bernardino  2019          365        55
#
#      ModerateDays  UnhealthyForSensitiveGroupsDays  UnhealthyDays  \
# 74             80                                6              0
# 35            209                               21              2
# ...

# %%
# Look up the top 10 counties with highest levels of COPD
aqi2019_df.loc[aqi2019_df['County'].isin(
    ['Lee',
     'Clay',
     'Kusilvak',
     'Bell',
     'McDowell',
     'Wolfe',
     'Harlan',
     'Leslie',
     'McCreary',
     'Knott'])]
# Out:
#            State County  Year  DaysWithAQI  GoodDays  ModerateDays  \
# 1        Alabama   Clay  2019          107        97            10
# 164      Florida    Lee  2019          365       328            36
# 305         Iowa    Lee  2019          120       101            19
# 326     Kentucky   Bell  2019          263       243            20
# 471  Mississippi    Lee  2019          241       222            19
# 479     Missouri   Clay  2019          365       295            70
# 834        Texas   Bell  2019          365       284            79
#
#      UnhealthyForSensitiveGroupsDays  UnhealthyDays  VeryUnhealthyDays  \
# 1                                  0              0                  0
# 164                                1              0                  0
# 305                                0              0                  0
# 326                                0              0                  0
# 471                                0              0                  0
# ...

# %% [markdown]
# # Loading in Data from 2009-2019

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2009.csv"
aqi2009_df = pd.read_csv(file_path)
aqi2009_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2009            252        218             32
# 1  Alabama     Clay  2009            119         97             22
# 2  Alabama  Colbert  2009            323        220            103
# 3  Alabama   DeKalb  2009            363        311             52
# 4  Alabama   Elmore  2009            244        228             16
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    2               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2010.csv"
aqi2010_df = pd.read_csv(file_path)
aqi2010_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2010            274        188             80
# 1  Alabama     Clay  2010            113         79             34
# 2  Alabama  Colbert  2010            355        208            146
# 3  Alabama   DeKalb  2010            358        248            106
# 4  Alabama   Elmore  2010            241        181             55
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    6               0                    0
# 1                                    0               0                    0
# 2                                    1               0                    0
# 3                                    4               0                    0
# 4                                    5               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2011.csv"
aqi2011_df = pd.read_csv(file_path)
aqi2011_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2011            282        204             69
# 1  Alabama     Clay  2011            118         80             38
# 2  Alabama  Colbert  2011            279        214             64
# 3  Alabama   DeKalb  2011            336        257             78
# 4  Alabama   Elmore  2011            242        192             48
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    9               0                    0
# 1                                    0               0                    0
# 2                                    1               0                    0
# 3                                    1               0                    0
# 4                                    2               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2012.csv"
aqi2012_df = pd.read_csv(file_path)
aqi2012_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2012            284        226             56
# 1  Alabama     Clay  2012            121         99             22
# 2  Alabama  Colbert  2012            283        222             55
# 3  Alabama   DeKalb  2012            361        282             74
# 4  Alabama   Elmore  2012            245        212             33
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    2               0                    0
# 1                                    0               0                    0
# 2                                    6               0                    0
# 3                                    5               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2013.csv"
aqi2013_df = pd.read_csv(file_path)
aqi2013_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2013            273        235             38
# 1  Alabama     Clay  2013            118        100             18
# 2  Alabama  Colbert  2013            285        252             33
# 3  Alabama   DeKalb  2013            360        319             41
# 4  Alabama   Elmore  2013            244        229             15
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2014.csv"
aqi2014_df = pd.read_csv(file_path)
aqi2014_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2014            280        232             46
# 1  Alabama     Clay  2014            114         96             18
# 2  Alabama  Colbert  2014            284        251             33
# 3  Alabama   DeKalb  2014            360        313             47
# 4  Alabama   Elmore  2014            245        224             21
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    2               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2015.csv"
aqi2015_df = pd.read_csv(file_path)
aqi2015_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2015            264        230             33
# 1  Alabama     Clay  2015            112        101             11
# 2  Alabama  Colbert  2015            280        251             29
# 3  Alabama   DeKalb  2015            363        319             43
# 4  Alabama   Elmore  2015            233        223              9
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    1               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    1               0                    0
# 4                                    1               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2016.csv"
aqi2016_df = pd.read_csv(file_path)
aqi2016_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2016            279        247             32
# 1  Alabama     Clay  2016            116        109              7
# 2  Alabama  Colbert  2016            282        258             23
# 3  Alabama   DeKalb  2016            348        304             43
# 4  Alabama   Elmore  2016            117        107             10
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    1               0                    0
# 3                                    1               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2017.csv"
aqi2017_df = pd.read_csv(file_path)
aqi2017_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2017            270        241             28
# 1  Alabama     Clay  2017            118        104             14
# 2  Alabama  Colbert  2017            283        265             18
# 3  Alabama   DeKalb  2017            359        329             30
# 4  Alabama   Elmore  2017            226        221              5
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    1               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2018.csv"
aqi2018_df = pd.read_csv(file_path)
aqi2018_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2018            270        245             25
# 1  Alabama     Clay  2018            110        103              7
# 2  Alabama  Colbert  2018            277        251             26
# 3  Alabama   DeKalb  2018            350        316             34
# 4  Alabama   Elmore  2018            222        203             19
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
# Create the dataframe
file_path = "./Resources/annual_aqi_by_county_2019.csv"
aqi2019_df = pd.read_csv(file_path)
aqi2019_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2019            271        237             34
# 1  Alabama     Clay  2019            107         97             10
# 2  Alabama  Colbert  2019            263        252             11
# 3  Alabama   DeKalb  2019            361        324             37
# 4  Alabama   Elmore  2019            228        208             20
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %% [markdown]
# # Processing the Dataframes

# %%
# # Create a list of all AQI dataframes to process
# df_list = [aqi2009_df, aqi2010_df, aqi2011_df, aqi2012_df, aqi2013_df,
#           aqi2014_df, aqi2015_df, aqi2016_df, aqi2017_df, aqi2018_df, aqi2019_df]

# %%
# # Create a for loop to process dataframes
# for dataframe in df_list:
#     dataframe = dataframe.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
#                       "Moderate Days", "Unhealthy for Sensitive Groups Days",
#                      "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# %%
# aqi2009_df.columns.tolist(), aqi2019_df.columns.tolist()

# %%
# Reduce the dataframes to only show columns of interest
aqi2009_df = aqi2009_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2010_df = aqi2010_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2011_df = aqi2011_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2012_df = aqi2012_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2013_df = aqi2013_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2014_df = aqi2014_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2015_df = aqi2015_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2016_df = aqi2016_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2017_df = aqi2017_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2018_df = aqi2018_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# Reduce the dataframes to only show columns of interest
aqi2019_df = aqi2019_df.filter(["State", "County", "Year", "Days with AQI", "Good Days", 
                      "Moderate Days", "Unhealthy for Sensitive Groups Days",
                     "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"], axis=1)

# %%
# Create a list of all AQI dataframes
df_list = [aqi2009_df, aqi2010_df, aqi2011_df, aqi2012_df, aqi2013_df,
          aqi2014_df, aqi2015_df, aqi2016_df, aqi2017_df, aqi2018_df, aqi2019_df]

# %%
# Check that we only have columns of interest
for dataframe in df_list:
    print(dataframe.columns.tolist())
# Out:
# ['State', 'County', 'Year', 'Days with AQI', 'Good Days', 'Moderate Days', 'Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days']
# ['State', 'County', 'Year', 'Days with AQI', 'Good Days', 'Moderate Days', 'Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days']
# ['State', 'County', 'Year', 'Days with AQI', 'Good Days', 'Moderate Days', 'Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days']
# ['State', 'County', 'Year', 'Days with AQI', 'Good Days', 'Moderate Days', 'Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days']
# ['State', 'County', 'Year', 'Days with AQI', 'Good Days', 'Moderate Days', 'Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days']
# ...

# %%
# Rename columns to match SQL schema
aqi2009_df = aqi2009_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2010_df = aqi2010_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2011_df = aqi2011_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2012_df = aqi2012_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2013_df = aqi2013_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2014_df = aqi2014_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2015_df = aqi2015_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2016_df = aqi2016_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2017_df = aqi2017_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2018_df = aqi2018_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# Rename columns to match SQL schema
aqi2019_df = aqi2019_df.set_axis(['State', 'County', 'Year', 'Days_with_AQI', 'Good_Days',
                                   'Moderate_Days', 'Unhealthy_for_Sensitive_Groups_Days',
                                   'Unhealthy_Days', 'Very_Unhealthy_Days', 'Hazardous_Days'], 
                                   axis=1, inplace=False)

# %%
aqi2009_df.head()
# Out:
#      State   County  Year  Days_with_AQI  Good_Days  Moderate_Days  \
# 0  Alabama  Baldwin  2009            252        218             32
# 1  Alabama     Clay  2009            119         97             22
# 2  Alabama  Colbert  2009            323        220            103
# 3  Alabama   DeKalb  2009            363        311             52
# 4  Alabama   Elmore  2009            244        228             16
#
#    Unhealthy_for_Sensitive_Groups_Days  Unhealthy_Days  Very_Unhealthy_Days  \
# 0                                    2               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous_Days
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
aqi2019_df.head()
# Out:
#      State   County  Year  Days_with_AQI  Good_Days  Moderate_Days  \
# 0  Alabama  Baldwin  2019            271        237             34
# 1  Alabama     Clay  2019            107         97             10
# 2  Alabama  Colbert  2019            263        252             11
# 3  Alabama   DeKalb  2019            361        324             37
# 4  Alabama   Elmore  2019            228        208             20
#
#    Unhealthy_for_Sensitive_Groups_Days  Unhealthy_Days  Very_Unhealthy_Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous_Days
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
# # Create a dataframe with "Days with AQI" for all years
# data = [aqi2009_df["Days with AQI"], aqi2010_df["Days with AQI"], aqi2011_df["Days with AQI"], 
#         aqi2012_df["Days with AQI"], aqi2013_df["Days with AQI"], aqi2014_df["Days with AQI"], 
#         aqi2015_df["Days with AQI"], aqi2016_df["Days with AQI"], aqi2017_df["Days with AQI"], 
#         aqi2018_df["Days with AQI"], aqi2019_df["Days with AQI"]]

# headers = ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]

# aqiDays_df = pd.concat(data, axis=1, keys=headers)

# aqiDays_df.head()
