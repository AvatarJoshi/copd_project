# %% [markdown]
# # Processing PLACES_2019 for ML and DataViz

# %%
# Dependencies
import pandas as pd

# %%
# This dataset is for 2019 but is from the 2021 release of PLACES
# https://chronicdata.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-County-Data-20/swc5-untb/data

# Load in PLACES dataset filtered for COPD
file_path = "Resources/PLACES_COPD.csv"
copd_df = pd.read_csv(file_path)

# Display all rows 
pd.set_option('display.max_columns', None)

# Show the dataframe
copd_df.head()
# Out:
#    Year StateAbbr StateDesc           LocationName DataSource  \
# 0  2019        IA      Iowa                   Cass      BRFSS
# 1  2019        IA      Iowa                 Monona      BRFSS
# 2  2019        AZ   Arizona                 Graham      BRFSS
# 3  2019        AK    Alaska  Prince of Wales-Hyder      BRFSS
# 4  2019        AK    Alaska             Dillingham      BRFSS
#
#           Category                                            Measure  \
# 0  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 1  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 2  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 3  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 4  Health Outcomes  Chronic obstructive pulmonary disease among ad...
#
#   Data_Value_Unit          Data_Value_Type  Data_Value  \
# 0               %         Crude prevalence         8.3
# 1               %         Crude prevalence         8.3
# 2               %  Age-adjusted prevalence         6.6
# 3               %  Age-adjusted prevalence         7.9
# 4               %         Crude prevalence         8.9
#
#    Data_Value_Footnote_Symbol  Data_Value_Footnote  Low_Confidence_Limit  \
# 0                         NaN                  NaN                   7.0
# 1                         NaN                  NaN                   7.0
# 2                         NaN                  NaN                   6.0
# 3                         NaN                  NaN                   7.2
# 4                         NaN                  NaN                   7.7
#
#    High_Confidence_Limit TotalPopulation  LocationID CategoryID MeasureId  \
# 0                    9.8          12,836       19029    HLTHOUT      COPD
# 1                    9.5           8,615       19133    HLTHOUT      COPD
# 2                    7.3          38,837        4009    HLTHOUT      COPD
# 3                    8.6           6,203        2198    HLTHOUT      COPD
# 4                   10.0           4,916        2070    HLTHOUT      COPD
#
#   DataValueTypeID Short_Question_Text                       Geolocation
# 0          CrdPrv                COPD  POINT (-94.92791359 41.33146007)
# 1          CrdPrv                COPD  POINT (-95.95997093 42.05236881)
# 2       AgeAdjPrv                COPD  POINT (-109.8871087 32.93306592)
# 3       AgeAdjPrv                COPD  POINT (-132.7096152 55.50495667)
# 4          CrdPrv                COPD  POINT (-158.2125392 59.79999618)

# %%
# This dataset is for 2019 but is from the 2021 release of PLACES
# https://chronicdata.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-County-Data-20/swc5-untb/data

# Load in PLACES dataset filtered for current smokers
file_path = "Resources/PLACES_smokers.csv"
smokers_df = pd.read_csv(file_path)

# Display all rows 
pd.set_option('display.max_columns', None)

# Show the dataframe
smokers_df.head()
# Out:
#    Year StateAbbr   StateDesc LocationName DataSource               Category  \
# 0  2019        CA  California       Sierra      BRFSS  Health Risk Behaviors
# 1  2019        CO    Colorado       Pitkin      BRFSS  Health Risk Behaviors
# 2  2019        CA  California    San Mateo      BRFSS  Health Risk Behaviors
# 3  2019        AL     Alabama         Dale      BRFSS  Health Risk Behaviors
# 4  2019        AR    Arkansas  St. Francis      BRFSS  Health Risk Behaviors
#
#                                         Measure Data_Value_Unit  \
# 0  Current smoking among adults aged >=18 years               %
# 1  Current smoking among adults aged >=18 years               %
# 2  Current smoking among adults aged >=18 years               %
# 3  Current smoking among adults aged >=18 years               %
# 4  Current smoking among adults aged >=18 years               %
#
#            Data_Value_Type  Data_Value  Data_Value_Footnote_Symbol  \
# 0         Crude prevalence        13.8                         NaN
# 1  Age-adjusted prevalence        11.0                         NaN
# 2         Crude prevalence         9.2                         NaN
# 3  Age-adjusted prevalence        22.0                         NaN
# 4         Crude prevalence        24.6                         NaN
#
#    Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                  NaN                  11.9                   15.6
# 1                  NaN                   8.7                   13.4
# 2                  NaN                   7.8                   10.5
# 3                  NaN                  19.4                   24.4
# 4                  NaN                  22.2                   26.8
#
#   TotalPopulation  LocationID CategoryID MeasureId DataValueTypeID  \
# 0           3,005        6091    RISKBEH  CSMOKING          CrdPrv
# 1          17,767        8097    RISKBEH  CSMOKING       AgeAdjPrv
# 2         766,573        6081    RISKBEH  CSMOKING          CrdPrv
# 3          49,172        1045    RISKBEH  CSMOKING       AgeAdjPrv
# 4          24,994        5123    RISKBEH  CSMOKING          CrdPrv
#
#   Short_Question_Text                       Geolocation
# 0     Current Smoking  POINT (-120.5160862 39.58014381)
# 1     Current Smoking  POINT (-106.9159741 39.21744595)
# 2     Current Smoking  POINT (-122.3273639 37.42322968)
# 3     Current Smoking  POINT (-85.61159073 31.43150889)
# 4     Current Smoking  POINT (-90.74737815 35.02173053)

# %%
# View rows and columns of the dataframe
print(copd_df.shape)
print(smokers_df.shape)
# Out:
# (6244, 21)
# (6244, 21)

# %%
# View unique values for columns
print(copd_df["Data_Value_Footnote"].unique())
print(copd_df["Year"].unique())
print(copd_df["DataSource"].unique())
print(copd_df["Data_Value_Footnote_Symbol"].unique())
print(copd_df["Data_Value_Footnote"].unique())
print(copd_df["CategoryID"].unique())
print(copd_df["MeasureId"].unique())
print(copd_df["DataValueTypeID"].unique())
print(copd_df["Short_Question_Text"].unique())
# Out:
# [nan]
# [2019]
# ['BRFSS']
# [nan]
# [nan]
# ['HLTHOUT']
# ['COPD']
# ['CrdPrv' 'AgeAdjPrv']
# ['COPD']

# %%
# View all columns
copd_df.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'DataSource',
#        'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'LocationID', 'CategoryID', 'MeasureId', 'DataValueTypeID',
#        'Short_Question_Text', 'Geolocation'],
#       dtype='object')

# %%
# Make a new column that merges county name ("LocationName") and the State ("StateAbbr")
copd_df["State_County"] = copd_df['LocationName'].astype(str) +", "+ copd_df["StateDesc"]

# Make a new column that merges county name ("LocationName") and the State ("StateAbbr")
smokers_df["State_County"] = smokers_df['LocationName'].astype(str) +", "+ smokers_df["StateDesc"]

# %%
# Remove uninformative columns
copd_df = copd_df.drop(["Data_Value_Footnote", "Year", "DataSource",
                           "Data_Value_Footnote_Symbol", "Data_Value_Footnote",
                           "CategoryID", "MeasureId", "DataValueTypeID",
                           "Short_Question_Text", "Category",
                           "StateAbbr"], axis=1)

smokers_df = smokers_df.drop(["Data_Value_Footnote", "Year", "DataSource",
                           "Data_Value_Footnote_Symbol", "Data_Value_Footnote",
                           "CategoryID", "MeasureId", "DataValueTypeID",
                           "Short_Question_Text", "Category", "LocationName",
                           "StateAbbr", "StateDesc"], axis=1)

# %%
# Filter out "Age-adjusted prevalence"
copd_df = copd_df[copd_df.Data_Value_Type != "Age-adjusted prevalence"]
smokers_df = smokers_df[smokers_df.Data_Value_Type != "Age-adjusted prevalence"]

# %%
# View copd dataframe
copd_df.head(2)
# Out:
#   StateDesc LocationName                                            Measure  \
# 0      Iowa         Cass  Chronic obstructive pulmonary disease among ad...
# 1      Iowa       Monona  Chronic obstructive pulmonary disease among ad...
#
#   Data_Value_Unit   Data_Value_Type  Data_Value  Low_Confidence_Limit  \
# 0               %  Crude prevalence         8.3                   7.0
# 1               %  Crude prevalence         8.3                   7.0
#
#    High_Confidence_Limit TotalPopulation  LocationID  \
# 0                    9.8          12,836       19029
# 1                    9.5           8,615       19133
#
#                         Geolocation  State_County
# 0  POINT (-94.92791359 41.33146007)    Cass, Iowa
# 1  POINT (-95.95997093 42.05236881)  Monona, Iowa

# %%
# View smokers dataframe
smokers_df.head(2)
# Out:
#                                         Measure Data_Value_Unit  \
# 0  Current smoking among adults aged >=18 years               %
# 2  Current smoking among adults aged >=18 years               %
#
#     Data_Value_Type  Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# 0  Crude prevalence        13.8                  11.9                   15.6
# 2  Crude prevalence         9.2                   7.8                   10.5
#
#   TotalPopulation  LocationID                       Geolocation  \
# 0           3,005        6091  POINT (-120.5160862 39.58014381)
# 2         766,573        6081  POINT (-122.3273639 37.42322968)
#
#             State_County
# 0     Sierra, California
# 2  San Mateo, California

# %%
# Merge copd and smokers dataframes
merged_df = pd.merge(copd_df, smokers_df, on="State_County")
merged_df.head(2)
# Out:
#   StateDesc LocationName                                          Measure_x  \
# 0      Iowa         Cass  Chronic obstructive pulmonary disease among ad...
# 1      Iowa       Monona  Chronic obstructive pulmonary disease among ad...
#
#   Data_Value_Unit_x Data_Value_Type_x  Data_Value_x  Low_Confidence_Limit_x  \
# 0                 %  Crude prevalence           8.3                     7.0
# 1                 %  Crude prevalence           8.3                     7.0
#
#    High_Confidence_Limit_x TotalPopulation_x  LocationID_x  \
# 0                      9.8            12,836         19029
# 1                      9.5             8,615         19133
#
#                       Geolocation_x  State_County  \
# 0  POINT (-94.92791359 41.33146007)    Cass, Iowa
# 1  POINT (-95.95997093 42.05236881)  Monona, Iowa
#
#                                       Measure_y Data_Value_Unit_y  \
# 0  Current smoking among adults aged >=18 years                 %
# 1  Current smoking among adults aged >=18 years                 %
#
#   Data_Value_Type_y  Data_Value_y  Low_Confidence_Limit_y  \
# 0  Crude prevalence          19.3                    16.4
# 1  Crude prevalence          18.5                    15.8
#
#    High_Confidence_Limit_y TotalPopulation_y  LocationID_y  \
# 0                     22.1            12,836         19029
# 1                     20.9             8,615         19133
#
#                       Geolocation_y
# 0  POINT (-94.92791359 41.33146007)
# 1  POINT (-95.95997093 42.05236881)

# %%
# Drop unnecessary columns
merged_df = merged_df.drop(["Measure_x", "Data_Value_Unit_x", "Data_Value_Type_x", "TotalPopulation_x",
                           "LocationID_x", "Geolocation_x", "Measure_y", "Data_Value_Unit_y", 
                            "Data_Value_Type_y", "Low_Confidence_Limit_x","High_Confidence_Limit_x", 
                            "Low_Confidence_Limit_y", "High_Confidence_Limit_y", "TotalPopulation_x"], axis=1)

# %%
# Check columns were dropped
merged_df.head()
# Out:
#   StateDesc       LocationName  Data_Value_x               State_County  \
# 0      Iowa               Cass           8.3                 Cass, Iowa
# 1      Iowa             Monona           8.3               Monona, Iowa
# 2    Alaska         Dillingham           8.9         Dillingham, Alaska
# 3  Colorado             Custer           7.5           Custer, Colorado
# 4    Alaska  Ketchikan Gateway           6.6  Ketchikan Gateway, Alaska
#
#    Data_Value_y TotalPopulation_y  LocationID_y  \
# 0          19.3            12,836         19029
# 1          18.5             8,615         19133
# 2          31.1             4,916          2070
# 3          13.8             5,068          8027
# 4          19.4            13,901          2130
#
#                       Geolocation_y
# 0  POINT (-94.92791359 41.33146007)
# 1  POINT (-95.95997093 42.05236881)
# 2  POINT (-158.2125392 59.79999618)
# 3  POINT (-105.3669993 38.10865771)
# 4  POINT (-130.9352394 55.58863162)

# %%
# Sort dataframe by levels of COPD
top10_df = merged_df.sort_values(by=['Data_Value_x'],  ascending=False).head(5)
top10_df
# Out:
#           StateDesc LocationName  Data_Value_x             State_County  \
# 3020  West Virginia     McDowell          18.2  McDowell, West Virginia
# 1179       Kentucky         Bell          17.4           Bell, Kentucky
# 1097       Kentucky          Lee          17.4            Lee, Kentucky
# 997        Kentucky        Wolfe          17.3          Wolfe, Kentucky
# 1105       Kentucky       Harlan          16.9         Harlan, Kentucky
#
#       Data_Value_y TotalPopulation_y  LocationID_y  \
# 3020          31.9            17,624         54047
# 1179          32.3            26,032         21013
# 1097          35.4             7,403         21129
# 997           32.6             7,157         21237
# 1105          31.0            26,010         21095
#
#                          Geolocation_y
# 3020  POINT (-81.65398301 37.37831053)
# 1179   POINT (-83.67371026 36.7310214)
# 1097  POINT (-83.71567753 37.59439368)
# 997   POINT (-83.49340584 37.73915782)
# 1105  POINT (-83.21787827 36.85671097)

# %%
top10_df["State_County"].tolist()
# Out:
# ['McDowell, West Virginia',
#  'Bell, Kentucky',
#  'Lee, Kentucky',
#  'Wolfe, Kentucky',
#  'Harlan, Kentucky']

# %%
merged_df.columns.tolist()
# Out:
# ['StateDesc',
#  'LocationName',
#  'Data_Value_x',
#  'State_County',
#  'Data_Value_y',
#  'TotalPopulation_y',
#  'LocationID_y',
#  'Geolocation_y']

# %%
# Working on renaming columns to something more digestable.
dict = {'TotalPopulation_y': "Total_Population",
        'Data_Value_x' :'Levels_COPD',
        'Data_Value_y': 'Levels_Smokers',
        'TotalPopulation_y': 'Total_Population',
        'LocationID_y': 'Location_ID',
        'Geolocation_y': 'Geolocation'
}
 
# call rename () method
merged_df.rename(columns=dict,
          inplace=True)

# View dataframe
merged_df.head()
# Out:
#   StateDesc       LocationName  Levels_COPD               State_County  \
# 0      Iowa               Cass          8.3                 Cass, Iowa
# 1      Iowa             Monona          8.3               Monona, Iowa
# 2    Alaska         Dillingham          8.9         Dillingham, Alaska
# 3  Colorado             Custer          7.5           Custer, Colorado
# 4    Alaska  Ketchikan Gateway          6.6  Ketchikan Gateway, Alaska
#
#    Levels_Smokers Total_Population  Location_ID  \
# 0            19.3           12,836        19029
# 1            18.5            8,615        19133
# 2            31.1            4,916         2070
# 3            13.8            5,068         8027
# 4            19.4           13,901         2130
#
#                         Geolocation
# 0  POINT (-94.92791359 41.33146007)
# 1  POINT (-95.95997093 42.05236881)
# 2  POINT (-158.2125392 59.79999618)
# 3  POINT (-105.3669993 38.10865771)
# 4  POINT (-130.9352394 55.58863162)

# %%
# For ML Model
# Reorder the columns
merged_df = merged_df[["State_County", "StateDesc", "LocationName", "Levels_Smokers", "Levels_COPD"]]

# View the dataframe
merged_df.head()
# Out:
#                 State_County StateDesc       LocationName  Levels_Smokers  \
# 0                 Cass, Iowa      Iowa               Cass            19.3
# 1               Monona, Iowa      Iowa             Monona            18.5
# 2         Dillingham, Alaska    Alaska         Dillingham            31.1
# 3           Custer, Colorado  Colorado             Custer            13.8
# 4  Ketchikan Gateway, Alaska    Alaska  Ketchikan Gateway            19.4
#
#    Levels_COPD
# 0          8.3
# 1          8.3
# 2          8.9
# 3          7.5
# 4          6.6

# %%
# Rename columns
merged_df.columns = ["State_County", "State", "County", "Levels_Smokers", "Levels_COPD"]
merged_df.head()
# Out:
#                 State_County     State             County  Levels_Smokers  \
# 0                 Cass, Iowa      Iowa               Cass            19.3
# 1               Monona, Iowa      Iowa             Monona            18.5
# 2         Dillingham, Alaska    Alaska         Dillingham            31.1
# 3           Custer, Colorado  Colorado             Custer            13.8
# 4  Ketchikan Gateway, Alaska    Alaska  Ketchikan Gateway            19.4
#
#    Levels_COPD
# 0          8.3
# 1          8.3
# 2          8.9
# 3          7.5
# 4          6.6

# %%
# # For DataViz
# # Reorder the columns
# merged_df = merged_df[["StateDesc", "LocationName", "Location_ID", "State_County", "Geolocation",
#                        "Levels_Smokers", "Levels_COPD"]]

# # View the dataframe
# merged_df.head()

# %%
# merged_df.loc[merged_df['State_County'] == 'Aleutians West, Alaska']

# %%
# Check the datatypes
merged_df.dtypes
# Out:
# State_County       object
# State              object
# County             object
# Levels_Smokers    float64
# Levels_COPD       float64
# dtype: object

# %%
# Export the dataframe to csv
merged_df.to_csv('./Resources/processed_PLACES_COPD.csv')
